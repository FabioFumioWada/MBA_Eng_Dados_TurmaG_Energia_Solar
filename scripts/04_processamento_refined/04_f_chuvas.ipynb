# %%
# %sql
CREATE TABLE IF NOT EXISTS mba.refined.f_chuvas(
    id_estacao BIGINT COMMENT 'Chave substituta do fato clima diário',
    anomes int COMMENT 'Ano mes referencia do periodo de chuvas',
    chuva_mm DOUBLE COMMENT 'Precipitação total do dia, em mm'
)
USING DELTA
COMMENT 'Fato mensal de chuva por estação meteorológica, agregado a partir das leituras horárias. Granularidade: estação x mes. Fonte: INMET - BDMEP, via mba.raw.clima_inmet.'

# %%
from pyspark.sql import functions as F

spark.sql(f"""
            select CAST(date_format(a.data, 'yyyyMM')AS INT) AS anomes
                , b.id_estacao
                , coalesce(sum(precipitacao_total_dia_mm),0) chuva_mm
            from mba.trusted.f_clima_diario a
            join mba.trusted.d_estacao_meterologica b on a.codigo_wmo =b.codigo_wmo
            group by all
          """).createOrReplaceTempView("stg_clima_diario")

# %%
# %sql
MERGE INTO mba.refined.f_chuvas AS tgt
USING stg_clima_diario AS src
ON tgt.id_estacao = src.id_estacao and tgt.anomes = src.anomes

WHEN MATCHED THEN
    UPDATE SET
        tgt.chuva_mm = src.chuva_mm

WHEN NOT MATCHED THEN
    INSERT ( id_estacao, anomes, chuva_mm )
    VALUES ( src.id_estacao, src.anomes, src.chuva_mm );

# %%
dbutils.notebook.exit("Executed")

# %%
# %sql
select * from mba.refined.f_chuvas a
join mba.trusted.d_estacao_meterologica b on a.id_estacao=b.id_estacao

# %%
# %sql
select * from mba.trusted.d_usinas a
join mba.trusted.d_estacao_meterologica b ON ST_DWithin(t1.geom, t2.geom, 100)

# %%
# %sql
SELECT 
    a.*, 
    b.*,
    -- Cálculo da distância em metros usando Haversine
    ( 6371000 * acos( 
        cos( radians(a.latitude) ) * cos( radians(b.latitude) ) * 
        cos( radians(b.longitude) - radians(a.longitude) ) + 
        sin( radians(a.latitude) ) * sin( radians(b.latitude) ) 
    ) ) AS distancia_metros
FROM mba.trusted.d_usinas a
INNER JOIN mba.trusted.d_estacao_meterologica b
    ON ( 6371000 * acos( 
        cos( radians(a.latitude) ) * cos( radians(b.latitude) ) * 
        cos( radians(b.longitude) - radians(a.longitude) ) + 
        sin( radians(a.latitude) ) * sin( radians(b.latitude) ) 
    ) ) <= 100 -- Raio máximo de aproximação em METROS (ex: 100 metros)

# %%
# %sql
SELECT 
    a.*, 
    b.*,
    -- Cálculo da distância em metros usando Haversine
    ( 6371000 * acos( 
        cos( radians(a.latitude) ) * cos( radians(b.latitude) ) * 
        cos( radians(b.longitude) - radians(a.longitude) ) + 
        sin( radians(a.latitude) ) * sin( radians(b.latitude) ) 
    ) ) AS distancia_metros
mba.trusted.d_usinas a
mba.trusted.d_estacao_meterologica b
    ON ( 6371000 * acos( 
        cos( radians(a.latitude) ) * cos( radians(b.latitude) ) * 
        cos( radians(b.longitude) - radians(a.longitude) ) + 
        sin( radians(a.latitude) ) * sin( radians(b.latitude) ) 
    ) ) <= 10000 -- Raio máximo de aproximação em METROS (ex: 100 metros)
